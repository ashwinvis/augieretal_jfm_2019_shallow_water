# %% [markdown]
# # Load Data -> Pandas Dataframe -> Latex tables

# %%
# %matplotlib inline
from table_utils import *
# Out:
# scipy == 1.2.0 ; pandas == 0.24.0 ; numpy == 1.16.0

# %%
df_paths = DataFrame({'key': list(paths_sim.keys()), 'path': list(paths_sim.values())},)
print(len(df_paths), 'directories')
# Out:
# 57 directories

# %% [markdown]
# # Load them!

# %%
df_noise = DataFrame(columns=pd_columns)
df_vort = DataFrame(columns=pd_columns)

# %%
# %%capture --no-stdout

for row in df_paths.values:
    key = row[0]
    path = row[1]
    keyparams = keyparams_from_path(path)
    s = pandas_from_path(path, key)

    if keyparams[0] == 'noise':
        df_noise = df_noise.append(s, ignore_index=True)
    else:
        df_vort = df_vort.append(s, ignore_index=True)

numeric_columns = pd_columns
numeric_columns.remove('short name')
df_noise[numeric_columns] = df_noise[numeric_columns].apply(pd.to_numeric)
df_vort[numeric_columns] = df_vort[numeric_columns].apply(pd.to_numeric)
# Out:
# No local maxima found in the distance curve
# The line is probably not polynomial, try plotting
# the distance curve with plt.plot(knee.xd, knee.yd)
# Also check that you aren't mistakenly setting the invert arguement

# %%
len(df_noise), len(df_vort)
# Out:
# (26, 31)

# %%
df_vort = clean_up(df_vort)
df_vort = sort_reindex(df_vort)
df_vort
# Out:
#      $n$  $c$  $\nu_8$  $f$  $\epsilon$  $\frac{k_{diss}}{k_f}$   $F_f$  \
# 1   1920   20 1.11e-12 7.54        1.03                    56.6  0.0555
# 2   1920   20 1.11e-12 3.37        1.03                    56.6  0.0555
# 3   1920   20 1.11e-12    0        1.02                    56.6  0.0553
# 4   1920   20 1.11e-12    0        1.02                    56.6  0.0554
# 5   1920   20 1.11e-12    0           1                    56.6   0.055
# 6   1920   20 1.11e-12    0        1.11                    56.6  0.0568
# 7   1920  100 1.11e-12 75.4       0.932                    56.6  0.0107
# 8   1920  100 1.11e-12 75.4       0.915                    56.6  0.0107
# 9   1920  100 1.11e-12 75.4        1.14                    56.6  0.0115
# 10  1920  100 1.11e-12 53.3       0.991                    56.6   0.011
# 11  1920  100 1.11e-12 53.3       0.998                    56.6   0.011
# 12  1920  100 1.11e-12 53.3        1.06                    56.6  0.0112
# 13  1920  100 1.11e-12 37.7        1.04                    56.6  0.0111
# 14  1920  100 1.11e-12 37.7        1.04                    56.6  0.0111
# 15  1920  100 1.11e-12 37.7        1.04                    56.6  0.0111
# 16  1920  100 1.11e-12 37.7        1.25                    56.6  0.0118
# 17  1920  100 1.11e-12 37.7        1.66                    56.6   0.013
# 18  1920  100 1.11e-12    0        1.02                    56.6  0.0111
# 19  1920  100 1.11e-12    0        1.02                    56.6  0.0111
# 20  1920  100 1.11e-12    0        1.01                    56.6   0.011
# 21  1920  100 1.11e-12    0        1.07                    56.6  0.0112
# 22  1920  100 1.11e-12    0        2.22                    56.6  0.0143
# 23  1920  400 1.11e-12    0        1.03                    56.6 0.00277
# 24  1920  400 1.11e-12    0        1.08                    56.6 0.00282
# 25  1920  400 1.11e-12    0        1.04                    56.6 0.00278
# 26  1920  400 1.11e-12    0        1.17                    56.6  0.0029
# 27  1920  400 1.11e-12    0        1.89                    56.6  0.0034
#
#     $Ro_f$  $Bu$  $\frac{<\bf \Omega_0 >}{{(P k_f^2)}^{2/3}}$  $E$  \
# 1    0.111     4                                         0.01 5.43
# 2    0.248    20                                            1 5.51
# 3      inf   inf                                         0.01 3.62
# 4      inf   inf                                          0.1 3.85
# 5      inf   inf                                            1 4.86
# 6      inf   inf                                           10   13
# 7   0.0107     1                                         0.01 16.6
# 8   0.0107     1                                          0.1 17.3
# 9   0.0115     1                                            1   33
# 10  0.0155     2                                         0.01 13.9
# 11  0.0155     2                                          0.1 15.4
# 12  0.0159     2                                            1 21.3
# 13  0.0222     4                                         0.01 11.9
# 14  0.0223     4                                          0.1 13.3
# 15  0.0223     4                                            1 15.6
# 16  0.0237     4                                           10 90.7
# 17   0.026     4                                          100  105
# 18     inf   inf                                         0.01 7.41
# 19     inf   inf                                          0.1 7.54
# 20     inf   inf                                            1 8.66
# 21     inf   inf                                           10 15.3
# 22     inf   inf                                          100   98
# 23     inf   inf                                         0.01 14.8
# 24     inf   inf                                          0.1 15.1
# 25     inf   inf                                            1 15.7
# 26     inf   inf                                           10 22.8
# 27     inf   inf                                          100  102
#
#     $t_{stat}$  $t_{\max}$                              short name
# 1            8        99.9   vortex_grid_c20nh1920Bu4.0efr1.00e-02
# 2         6.52        99.8  vortex_grid_c20nh1920Bu20.0efr1.00e+00
# 3         5.71        49.8   vortex_grid_c20nh1920Buinfefr1.00e-02
# 4         5.71        99.9   vortex_grid_c20nh1920Buinfefr1.00e-01
# 5         5.41        49.9   vortex_grid_c20nh1920Buinfefr1.00e+00
# 6         3.62        99.8   vortex_grid_c20nh1920Buinfefr1.00e+01
# 7         22.6        99.8  vortex_grid_c100nh1920Bu1.0efr1.00e-02
# 8         22.9        99.8  vortex_grid_c100nh1920Bu1.0efr1.00e-01
# 9         22.7        99.8  vortex_grid_c100nh1920Bu1.0efr1.00e+00
# 10        19.2        99.8  vortex_grid_c100nh1920Bu2.0efr1.00e-02
# 11        19.3        99.8  vortex_grid_c100nh1920Bu2.0efr1.00e-01
# 12        19.4        99.8  vortex_grid_c100nh1920Bu2.0efr1.00e+00
# 13        16.8        99.9  vortex_grid_c100nh1920Bu4.0efr1.00e-02
# 14        16.6        99.9  vortex_grid_c100nh1920Bu4.0efr1.00e-01
# 15        16.3        99.9  vortex_grid_c100nh1920Bu4.0efr1.00e+00
# 16        12.7        99.9  vortex_grid_c100nh1920Bu4.0efr1.00e+01
# 17         1.6        99.9  vortex_grid_c100nh1920Bu4.0efr1.00e+02
# 18        11.1        99.9  vortex_grid_c100nh1920Buinfefr1.00e-02
# 19        11.1        99.9  vortex_grid_c100nh1920Buinfefr1.00e-01
# 20        10.7        49.9  vortex_grid_c100nh1920Buinfefr1.00e+00
# 21        8.72        99.9  vortex_grid_c100nh1920Buinfefr1.00e+01
# 22         1.5        49.9  vortex_grid_c100nh1920Buinfefr1.00e+02
# 23        20.7        49.8  vortex_grid_c400nh1920Buinfefr1.00e-02
# 24        19.3        99.9  vortex_grid_c400nh1920Buinfefr1.00e-01
# 25        18.4        49.8  vortex_grid_c400nh1920Buinfefr1.00e+00
# 26        18.3        99.9  vortex_grid_c400nh1920Buinfefr1.00e+01
# 27           5        49.8  vortex_grid_c400nh1920Buinfefr1.00e+02

# %%
df_noise = clean_up(df_noise)
df_noise = sort_reindex(df_noise)
df_noise
# Out:
#      $n$  $c$  $\nu_8$  $f$  $\epsilon$  $\frac{k_{diss}}{k_f}$   $F_f$  \
# 1    960   10 1.56e-10    0        1.04                    28.8   0.111
# 2   1920   10 9.68e-13    0        1.06                    57.7   0.112
# 3   3840   10    6e-15    0         1.1                     115   0.113
# 4   7680   10 3.72e-17    0        1.18                     231   0.116
# 5    960   20 1.56e-10    0           1                    28.8   0.055
# 6   1920   20 9.68e-13 21.3       0.838                    57.7  0.0518
# 7   1920   20 9.68e-13 15.1       0.894                    57.7  0.0529
# 8   1920   20 9.68e-13 10.7       0.938                    57.7  0.0538
# 9   1920   20 9.68e-13 7.54        0.98                    57.7  0.0546
# 10  1920   20 9.69e-13    0        1.02                    57.7  0.0553
# 11  3840   20 6.01e-15    0        1.08                     115  0.0563
# 12  7680   20 3.72e-17    0        1.21                     231  0.0585
# 13   960   40 1.56e-10    0       0.996                    28.8  0.0274
# 14  1920   40 9.68e-13    0       0.998                    57.7  0.0274
# 15  3840   40    6e-15    0        1.06                     115   0.028
# 16   960  100 1.56e-10    0       0.999                    28.8   0.011
# 17  1920  100 9.69e-13    0        1.01                    57.7   0.011
# 18  3840  100 6.01e-15    0        1.06                     115  0.0112
# 19  7680  100 3.72e-17    0        1.22                     231  0.0117
# 20   960  400 1.56e-10    0        1.14                    28.8 0.00287
# 21  1920  400 9.69e-13    0        1.15                    57.7 0.00288
# 22  3840  400 6.01e-15    0        1.12                     115 0.00286
# 23   960  700 1.56e-10    0        1.27                    28.8  0.0017
# 24  1920  700 9.68e-13    0        1.05                    57.7  0.0016
#
#     $Ro_f$  $Bu$  $\frac{<\bf \Omega_0 >}{{(P k_f^2)}^{2/3}}$  $E$  \
# 1      inf   inf                                            1 2.63
# 2      inf   inf                                            1 3.01
# 3      inf   inf                                            1  3.6
# 4      inf   inf                                            1  4.5
# 5      inf   inf                                            1 3.12
# 6   0.0366   0.5                                            1 7.92
# 7   0.0529     1                                            1 5.58
# 8   0.0761     2                                            1 4.36
# 9    0.109     4                                            1 3.94
# 10     inf   inf                                            1 3.64
# 11     inf   inf                                            1 4.49
# 12     inf   inf                                            1 5.77
# 13     inf   inf                                            1 3.95
# 14     inf   inf                                            1 4.78
# 15     inf   inf                                            1 6.07
# 16     inf   inf                                            1 5.92
# 17     inf   inf                                            1 7.38
# 18     inf   inf                                            1 9.41
# 19     inf   inf                                            1 12.6
# 20     inf   inf                                            1 12.3
# 21     inf   inf                                            1 15.5
# 22     inf   inf                                            1 19.2
# 23     inf   inf                                            1 16.9
# 24     inf   inf                                            1 19.5
#
#     $t_{stat}$  $t_{\max}$             short name
# 1         4.45        49.9    noise_c10nh960Buinf
# 2         4.66        49.8   noise_c10nh1920Buinf
# 3         5.22        49.9   noise_c10nh3840Buinf
# 4         6.12        16.9   noise_c10nh7680Buinf
# 5         4.88        49.9    noise_c20nh960Buinf
# 6           11        99.9   noise_c20nh1920Bu0.5
# 7         7.92        99.8   noise_c20nh1920Bu1.0
# 8         6.62        99.8   noise_c20nh1920Bu2.0
# 9         6.12        99.8   noise_c20nh1920Bu4.0
# 10        5.61         120   noise_c20nh1920Buinf
# 11        6.92         120   noise_c20nh3840Buinf
# 12        8.52         120   noise_c20nh7680Buinf
# 13        6.02        49.8    noise_c40nh960Buinf
# 14        7.12        49.8   noise_c40nh1920Buinf
# 15        8.72        49.8   noise_c40nh3840Buinf
# 16        8.72        49.8   noise_c100nh960Buinf
# 17        10.2         120  noise_c100nh1920Buinf
# 18        13.9         120  noise_c100nh3840Buinf
# 19        17.2        95.8  noise_c100nh7680Buinf
# 20        15.9         120   noise_c400nh960Buinf
# 21        21.3         120  noise_c400nh1920Buinf
# 22        25.5         119  noise_c400nh3840Buinf
# 23        19.1        49.8   noise_c700nh960Buinf
# 24        22.2        49.8  noise_c700nh1920Buinf

# %% [markdown]
# # Prepare final dataframes

# %% [markdown]
# ### Only waves

# %%
groups = df_noise.groupby(r'$Ro_f$')

df_w = sort_reindex(
    groups.filter(
        lambda x:all(x['$Ro_f$'] == np.inf),
        dropna=True
    ),
    prefix='W'
)
df_w
# Out:
#       $n$  $c$  $\nu_8$  $f$  $\epsilon$  $\frac{k_{diss}}{k_f}$   $F_f$  \
# W1    960   10 1.56e-10    0        1.04                    28.8   0.111
# W2   1920   10 9.68e-13    0        1.06                    57.7   0.112
# W3   3840   10    6e-15    0         1.1                     115   0.113
# W4   7680   10 3.72e-17    0        1.18                     231   0.116
# W5    960   20 1.56e-10    0           1                    28.8   0.055
# W6   1920   20 9.69e-13    0        1.02                    57.7  0.0553
# W7   3840   20 6.01e-15    0        1.08                     115  0.0563
# W8   7680   20 3.72e-17    0        1.21                     231  0.0585
# W9    960   40 1.56e-10    0       0.996                    28.8  0.0274
# W10  1920   40 9.68e-13    0       0.998                    57.7  0.0274
# W11  3840   40    6e-15    0        1.06                     115   0.028
# W12   960  100 1.56e-10    0       0.999                    28.8   0.011
# W13  1920  100 9.69e-13    0        1.01                    57.7   0.011
# W14  3840  100 6.01e-15    0        1.06                     115  0.0112
# W15  7680  100 3.72e-17    0        1.22                     231  0.0117
# W16   960  400 1.56e-10    0        1.14                    28.8 0.00287
# W17  1920  400 9.69e-13    0        1.15                    57.7 0.00288
# W18  3840  400 6.01e-15    0        1.12                     115 0.00286
# W19   960  700 1.56e-10    0        1.27                    28.8  0.0017
# W20  1920  700 9.68e-13    0        1.05                    57.7  0.0016
#
#      $Ro_f$  $Bu$  $\frac{<\bf \Omega_0 >}{{(P k_f^2)}^{2/3}}$  $E$  \
# W1      inf   inf                                            1 2.63
# W2      inf   inf                                            1 3.01
# W3      inf   inf                                            1  3.6
# W4      inf   inf                                            1  4.5
# W5      inf   inf                                            1 3.12
# W6      inf   inf                                            1 3.64
# W7      inf   inf                                            1 4.49
# W8      inf   inf                                            1 5.77
# W9      inf   inf                                            1 3.95
# W10     inf   inf                                            1 4.78
# W11     inf   inf                                            1 6.07
# W12     inf   inf                                            1 5.92
# W13     inf   inf                                            1 7.38
# W14     inf   inf                                            1 9.41
# W15     inf   inf                                            1 12.6
# W16     inf   inf                                            1 12.3
# W17     inf   inf                                            1 15.5
# W18     inf   inf                                            1 19.2
# W19     inf   inf                                            1 16.9
# W20     inf   inf                                            1 19.5
#
#      $t_{stat}$  $t_{\max}$             short name
# W1         4.45        49.9    noise_c10nh960Buinf
# W2         4.66        49.8   noise_c10nh1920Buinf
# W3         5.22        49.9   noise_c10nh3840Buinf
# W4         6.12        16.9   noise_c10nh7680Buinf
# W5         4.88        49.9    noise_c20nh960Buinf
# W6         5.61         120   noise_c20nh1920Buinf
# W7         6.92         120   noise_c20nh3840Buinf
# W8         8.52         120   noise_c20nh7680Buinf
# W9         6.02        49.8    noise_c40nh960Buinf
# W10        7.12        49.8   noise_c40nh1920Buinf
# W11        8.72        49.8   noise_c40nh3840Buinf
# W12        8.72        49.8   noise_c100nh960Buinf
# W13        10.2         120  noise_c100nh1920Buinf
# W14        13.9         120  noise_c100nh3840Buinf
# W15        17.2        95.8  noise_c100nh7680Buinf
# W16        15.9         120   noise_c400nh960Buinf
# W17        21.3         120  noise_c400nh1920Buinf
# W18        25.5         119  noise_c400nh3840Buinf
# W19        19.1        49.8   noise_c700nh960Buinf
# W20        22.2        49.8  noise_c700nh1920Buinf

# %% [markdown]
# ### Only waves and rotation

# %%
"""
groups = df_noise.groupby(['$n$', '$c$'])

df_wr = sort_reindex(
    groups.filter(
        lambda x:all(x['$n$'] == 1920) and all(x['$c$'] == 20),
        dropna=True
    ),
    prefix='WR'
)
df_wr
"""
groups = df_noise.groupby(['$n$', '$Ro_f$'])

df_wr = sort_reindex(
    groups.filter(
        lambda x:all(x['$Ro_f$'] < np.inf),
        dropna=True
    ),
    prefix='WR'
)
df_wr
# Out:
#       $n$  $c$  $\nu_8$  $f$  $\epsilon$  $\frac{k_{diss}}{k_f}$  $F_f$  \
# WR1  1920   20 9.68e-13 21.3       0.838                    57.7 0.0518
# WR2  1920   20 9.68e-13 15.1       0.894                    57.7 0.0529
# WR3  1920   20 9.68e-13 10.7       0.938                    57.7 0.0538
# WR4  1920   20 9.68e-13 7.54        0.98                    57.7 0.0546
#
#      $Ro_f$  $Bu$  $\frac{<\bf \Omega_0 >}{{(P k_f^2)}^{2/3}}$  $E$  \
# WR1  0.0366   0.5                                            1 7.92
# WR2  0.0529     1                                            1 5.58
# WR3  0.0761     2                                            1 4.36
# WR4   0.109     4                                            1 3.94
#
#      $t_{stat}$  $t_{\max}$            short name
# WR1          11        99.9  noise_c20nh1920Bu0.5
# WR2        7.92        99.8  noise_c20nh1920Bu1.0
# WR3        6.62        99.8  noise_c20nh1920Bu2.0
# WR4        6.12        99.8  noise_c20nh1920Bu4.0

# %% [markdown]
# ### Wave-vortex

# %%
groups = df_vort.groupby(r'$Ro_f$')

df_wv = sort_reindex(
    groups.filter(
        lambda x:all(x['$Ro_f$'] == np.inf),
        dropna=True
    ),
    prefix='WV'
)
df_wv
# Out:
#        $n$  $c$  $\nu_8$  $f$  $\epsilon$  $\frac{k_{diss}}{k_f}$   $F_f$  \
# WV1   1920   20 1.11e-12    0        1.02                    56.6  0.0553
# WV2   1920   20 1.11e-12    0        1.02                    56.6  0.0554
# WV3   1920   20 1.11e-12    0           1                    56.6   0.055
# WV4   1920   20 1.11e-12    0        1.11                    56.6  0.0568
# WV5   1920  100 1.11e-12    0        1.02                    56.6  0.0111
# WV6   1920  100 1.11e-12    0        1.02                    56.6  0.0111
# WV7   1920  100 1.11e-12    0        1.01                    56.6   0.011
# WV8   1920  100 1.11e-12    0        1.07                    56.6  0.0112
# WV9   1920  100 1.11e-12    0        2.22                    56.6  0.0143
# WV10  1920  400 1.11e-12    0        1.03                    56.6 0.00277
# WV11  1920  400 1.11e-12    0        1.08                    56.6 0.00282
# WV12  1920  400 1.11e-12    0        1.04                    56.6 0.00278
# WV13  1920  400 1.11e-12    0        1.17                    56.6  0.0029
# WV14  1920  400 1.11e-12    0        1.89                    56.6  0.0034
#
#       $Ro_f$  $Bu$  $\frac{<\bf \Omega_0 >}{{(P k_f^2)}^{2/3}}$  $E$  \
# WV1      inf   inf                                         0.01 3.62
# WV2      inf   inf                                          0.1 3.85
# WV3      inf   inf                                            1 4.86
# WV4      inf   inf                                           10   13
# WV5      inf   inf                                         0.01 7.41
# WV6      inf   inf                                          0.1 7.54
# WV7      inf   inf                                            1 8.66
# WV8      inf   inf                                           10 15.3
# WV9      inf   inf                                          100   98
# WV10     inf   inf                                         0.01 14.8
# WV11     inf   inf                                          0.1 15.1
# WV12     inf   inf                                            1 15.7
# WV13     inf   inf                                           10 22.8
# WV14     inf   inf                                          100  102
#
#       $t_{stat}$  $t_{\max}$                              short name
# WV1         5.71        49.8   vortex_grid_c20nh1920Buinfefr1.00e-02
# WV2         5.71        99.9   vortex_grid_c20nh1920Buinfefr1.00e-01
# WV3         5.41        49.9   vortex_grid_c20nh1920Buinfefr1.00e+00
# WV4         3.62        99.8   vortex_grid_c20nh1920Buinfefr1.00e+01
# WV5         11.1        99.9  vortex_grid_c100nh1920Buinfefr1.00e-02
# WV6         11.1        99.9  vortex_grid_c100nh1920Buinfefr1.00e-01
# WV7         10.7        49.9  vortex_grid_c100nh1920Buinfefr1.00e+00
# WV8         8.72        99.9  vortex_grid_c100nh1920Buinfefr1.00e+01
# WV9          1.5        49.9  vortex_grid_c100nh1920Buinfefr1.00e+02
# WV10        20.7        49.8  vortex_grid_c400nh1920Buinfefr1.00e-02
# WV11        19.3        99.9  vortex_grid_c400nh1920Buinfefr1.00e-01
# WV12        18.4        49.8  vortex_grid_c400nh1920Buinfefr1.00e+00
# WV13        18.3        99.9  vortex_grid_c400nh1920Buinfefr1.00e+01
# WV14           5        49.8  vortex_grid_c400nh1920Buinfefr1.00e+02

# %% [markdown]
# ### Waves-vortex and rotation

# %%
groups = df_vort.groupby(['$n$', '$Ro_f$'])

df_wvr = sort_reindex(
    groups.filter(
        lambda x:all(x['$Ro_f$'] < np.inf),
        dropna=True
    ),
    prefix='WVR'
)
df_wvr
# Out:
#         $n$  $c$  $\nu_8$  $f$  $\epsilon$  $\frac{k_{diss}}{k_f}$  $F_f$  \
# WVR1   1920   20 1.11e-12 7.54        1.03                    56.6 0.0555
# WVR2   1920   20 1.11e-12 3.37        1.03                    56.6 0.0555
# WVR3   1920  100 1.11e-12 75.4       0.932                    56.6 0.0107
# WVR4   1920  100 1.11e-12 75.4       0.915                    56.6 0.0107
# WVR5   1920  100 1.11e-12 75.4        1.14                    56.6 0.0115
# WVR6   1920  100 1.11e-12 53.3       0.991                    56.6  0.011
# WVR7   1920  100 1.11e-12 53.3       0.998                    56.6  0.011
# WVR8   1920  100 1.11e-12 53.3        1.06                    56.6 0.0112
# WVR9   1920  100 1.11e-12 37.7        1.04                    56.6 0.0111
# WVR10  1920  100 1.11e-12 37.7        1.04                    56.6 0.0111
# WVR11  1920  100 1.11e-12 37.7        1.04                    56.6 0.0111
# WVR12  1920  100 1.11e-12 37.7        1.25                    56.6 0.0118
# WVR13  1920  100 1.11e-12 37.7        1.66                    56.6  0.013
#
#        $Ro_f$  $Bu$  $\frac{<\bf \Omega_0 >}{{(P k_f^2)}^{2/3}}$  $E$  \
# WVR1    0.111     4                                         0.01 5.43
# WVR2    0.248    20                                            1 5.51
# WVR3   0.0107     1                                         0.01 16.6
# WVR4   0.0107     1                                          0.1 17.3
# WVR5   0.0115     1                                            1   33
# WVR6   0.0155     2                                         0.01 13.9
# WVR7   0.0155     2                                          0.1 15.4
# WVR8   0.0159     2                                            1 21.3
# WVR9   0.0222     4                                         0.01 11.9
# WVR10  0.0223     4                                          0.1 13.3
# WVR11  0.0223     4                                            1 15.6
# WVR12  0.0237     4                                           10 90.7
# WVR13   0.026     4                                          100  105
#
#        $t_{stat}$  $t_{\max}$                              short name
# WVR1            8        99.9   vortex_grid_c20nh1920Bu4.0efr1.00e-02
# WVR2         6.52        99.8  vortex_grid_c20nh1920Bu20.0efr1.00e+00
# WVR3         22.6        99.8  vortex_grid_c100nh1920Bu1.0efr1.00e-02
# WVR4         22.9        99.8  vortex_grid_c100nh1920Bu1.0efr1.00e-01
# WVR5         22.7        99.8  vortex_grid_c100nh1920Bu1.0efr1.00e+00
# WVR6         19.2        99.8  vortex_grid_c100nh1920Bu2.0efr1.00e-02
# WVR7         19.3        99.8  vortex_grid_c100nh1920Bu2.0efr1.00e-01
# WVR8         19.4        99.8  vortex_grid_c100nh1920Bu2.0efr1.00e+00
# WVR9         16.8        99.9  vortex_grid_c100nh1920Bu4.0efr1.00e-02
# WVR10        16.6        99.9  vortex_grid_c100nh1920Bu4.0efr1.00e-01
# WVR11        16.3        99.9  vortex_grid_c100nh1920Bu4.0efr1.00e+00
# WVR12        12.7        99.9  vortex_grid_c100nh1920Bu4.0efr1.00e+01
# WVR13         1.6        99.9  vortex_grid_c100nh1920Bu4.0efr1.00e+02

# %%
print(sum([len(df) for df in (df_w, df_wr, df_wv, df_wvr)]))
print(sum([len(df) for df in (df_noise, df_vort)]))
# Out:
# 51
# 51

# %% [markdown]
# # To $\LaTeX$

# %%
import os

# filename = 'jupyter'
filename = '../Latex/table_runs.tex'
if os.path.exists(filename):
    os.remove(filename)

if filename.endswith('.tex'):
    with open(filename, 'a') as f:
        f.write(r"""
\documentclass[a4paper]{article}
\usepackage[margin=1in]{geometry}

\begin{document}
\section{List of runs}


\subsection{Glossary}
\begin{itemize}
    \item W : Only waves runs
    \item WR : Only waves runs with rotation
    \item WV : Wave-vortex runs
    \item WVR : Wave-vortex runs with rotation
    \item $t_{stat}$ : Time when the run is approximately stationary
    \item $t_{max}$ : Time until which the run was simulated
""")
        f.write(
            '    \item {} : Initial enstrophy - forcing power ratio'.format(EFR))
        f.write('\n\end{itemize}')
        f.write(
            '\n\n\subsection{Tables}\n')

    
to_latex(df_w, ['$f$', '$Ro_f$', '$Bu$', EFR, '$E$', 'short name'], filename)
to_latex(df_wr, [EFR, '$E$', 'short name'], filename)
to_latex(df_wv, ['$f$', '$Ro_f$', '$Bu$', '$E$', 'short name'], filename)
to_latex(df_wvr, ['$E$', 'short name'], filename)


if filename.endswith('.tex'):
    with open(filename, 'a') as f:
        f.write('\end{document}')

# %%
# !pandoc  -V geometry:margin=1in -o ../Latex/table_runs.pdf ../Latex/table_runs.tex

# %%
pd.merge(df_w, df_noise)
# Out:
#      $n$  $c$  $\nu_8$  $f$  $\epsilon$  $\frac{k_{diss}}{k_f}$   $F_f$  \
# 0    960   10 1.56e-10    0        1.04                    28.8   0.111
# 1   1920   10 9.68e-13    0        1.06                    57.7   0.112
# 2   3840   10    6e-15    0         1.1                     115   0.113
# 3   7680   10 3.72e-17    0        1.18                     231   0.116
# 4    960   20 1.56e-10    0           1                    28.8   0.055
# 5   1920   20 9.69e-13    0        1.02                    57.7  0.0553
# 6   3840   20 6.01e-15    0        1.08                     115  0.0563
# 7   7680   20 3.72e-17    0        1.21                     231  0.0585
# 8    960   40 1.56e-10    0       0.996                    28.8  0.0274
# 9   1920   40 9.68e-13    0       0.998                    57.7  0.0274
# 10  3840   40    6e-15    0        1.06                     115   0.028
# 11   960  100 1.56e-10    0       0.999                    28.8   0.011
# 12  1920  100 9.69e-13    0        1.01                    57.7   0.011
# 13  3840  100 6.01e-15    0        1.06                     115  0.0112
# 14  7680  100 3.72e-17    0        1.22                     231  0.0117
# 15   960  400 1.56e-10    0        1.14                    28.8 0.00287
# 16  1920  400 9.69e-13    0        1.15                    57.7 0.00288
# 17  3840  400 6.01e-15    0        1.12                     115 0.00286
# 18   960  700 1.56e-10    0        1.27                    28.8  0.0017
# 19  1920  700 9.68e-13    0        1.05                    57.7  0.0016
#
#     $Ro_f$  $Bu$  $\frac{<\bf \Omega_0 >}{{(P k_f^2)}^{2/3}}$  $E$  \
# 0      inf   inf                                            1 2.63
# 1      inf   inf                                            1 3.01
# 2      inf   inf                                            1  3.6
# 3      inf   inf                                            1  4.5
# 4      inf   inf                                            1 3.12
# 5      inf   inf                                            1 3.64
# 6      inf   inf                                            1 4.49
# 7      inf   inf                                            1 5.77
# 8      inf   inf                                            1 3.95
# 9      inf   inf                                            1 4.78
# 10     inf   inf                                            1 6.07
# 11     inf   inf                                            1 5.92
# 12     inf   inf                                            1 7.38
# 13     inf   inf                                            1 9.41
# 14     inf   inf                                            1 12.6
# 15     inf   inf                                            1 12.3
# 16     inf   inf                                            1 15.5
# 17     inf   inf                                            1 19.2
# 18     inf   inf                                            1 16.9
# 19     inf   inf                                            1 19.5
#
#     $t_{stat}$  $t_{\max}$             short name
# 0         4.45        49.9    noise_c10nh960Buinf
# 1         4.66        49.8   noise_c10nh1920Buinf
# 2         5.22        49.9   noise_c10nh3840Buinf
# 3         6.12        16.9   noise_c10nh7680Buinf
# 4         4.88        49.9    noise_c20nh960Buinf
# 5         5.61         120   noise_c20nh1920Buinf
# 6         6.92         120   noise_c20nh3840Buinf
# 7         8.52         120   noise_c20nh7680Buinf
# 8         6.02        49.8    noise_c40nh960Buinf
# 9         7.12        49.8   noise_c40nh1920Buinf
# 10        8.72        49.8   noise_c40nh3840Buinf
# 11        8.72        49.8   noise_c100nh960Buinf
# 12        10.2         120  noise_c100nh1920Buinf
# 13        13.9         120  noise_c100nh3840Buinf
# 14        17.2        95.8  noise_c100nh7680Buinf
# 15        15.9         120   noise_c400nh960Buinf
# 16        21.3         120  noise_c400nh1920Buinf
# 17        25.5         119  noise_c400nh3840Buinf
# 18        19.1        49.8   noise_c700nh960Buinf
# 19        22.2        49.8  noise_c700nh1920Buinf

# %% [markdown]
# # To JSON

# %%
# !mkdir -p dataframes

# %%
for var in [name for name in vars() if name.startswith("df")]:
    _df = vars()[var]
    _df.to_csv(f"dataframes/{var}.csv")
