# %%
# %matplotlib inline
from table_utils import *

# %%
df_paths = DataFrame({'key': list(paths_lap.keys()), 'path': list(paths_lap.values())},)
print(len(df_paths), 'directories')
# Out:
# 13 directories

# %% [markdown]
# # Load them!

# %%
df_lap = DataFrame(columns=pd_columns)

# %%
# %%capture --no-stdout

for row in df_paths.values:
    key = row[0]
    path = row[1]
    print(path)
    keyparams = keyparams_from_path(path)
    s = pandas_from_path(path, key)
    df_lap = df_lap.append(s, ignore_index=True)
# Out:
# /media/avmo/lacie/13KTH/laplacian_nupt1/SW1Lwaves_noise_c=100_Bu=inf_beta=0.0_2880x2880_S50x50_2019-02-01_16-46-56
# /media/avmo/lacie/13KTH/laplacian_nupt1/SW1Lwaves_noise_c=100_Bu=inf_beta=0.0_960x960_S50x50_2019-02-01_16-44-54
# /media/avmo/lacie/13KTH/laplacian_nupt1/SW1Lwaves_noise_c=10_Bu=inf_beta=0.0_1920x1920_S50x50_2019-02-05_14-34-40
# /media/avmo/lacie/13KTH/laplacian_nupt1/SW1Lwaves_noise_c=10_Bu=inf_beta=0.0_2880x2880_S50x50_2019-02-01_16-45-22
# /media/avmo/lacie/13KTH/laplacian_nupt1/SW1Lwaves_noise_c=10_Bu=inf_beta=0.0_3840x3840_S50x50_2019-02-05_14-34-41
# /media/avmo/lacie/13KTH/laplacian_nupt1/SW1Lwaves_noise_c=10_Bu=inf_beta=0.0_7680x7680_S50x50_2019-02-05_14-34-41
# /media/avmo/lacie/13KTH/laplacian_nupt1/SW1Lwaves_noise_c=10_Bu=inf_beta=0.0_960x960_S50x50_2019-02-01_16-44-24
# /media/avmo/lacie/13KTH/laplacian_nupt1/SW1Lwaves_noise_c=200_Bu=inf_beta=0.0_2880x2880_S50x50_2019-02-01_16-46-57
# /media/avmo/lacie/13KTH/laplacian_nupt1/SW1Lwaves_noise_c=200_Bu=inf_beta=0.0_960x960_S50x50_2019-02-01_16-44-55
# /media/avmo/lacie/13KTH/laplacian_nupt1/SW1Lwaves_noise_c=20_Bu=inf_beta=0.0_2880x2880_S50x50_2019-02-01_16-46-55
# /media/avmo/lacie/13KTH/laplacian_nupt1/SW1Lwaves_noise_c=20_Bu=inf_beta=0.0_960x960_S50x50_2019-02-01_16-44-24
# /media/avmo/lacie/13KTH/laplacian_nupt1/SW1Lwaves_noise_c=40_Bu=inf_beta=0.0_2880x2880_S50x50_2019-02-01_16-46-55
# /media/avmo/lacie/13KTH/laplacian_nupt1/SW1Lwaves_noise_c=40_Bu=inf_beta=0.0_960x960_S50x50_2019-02-01_16-44-54

# %%
df_lap.head()
# Out:
#     $n$  $c$  $\nu_8$  $\nu_2$  $f$  $\epsilon$  $\frac{k_{diss}}{k_f}$  \
# 0  2880  100        0   0.0328    0       0.961                    67.9
# 1   960  100        0   0.0985    0       0.976                    22.6
# 2  1920   10        0   0.0492    0       0.985                    45.3
# 3  2880   10        0   0.0328    0       0.984                    67.9
# 4  3840   10        0   0.0246    0       0.993                    90.5
#
#    $F_f$  $Ro_f$ $Bu$  $\frac{<\bf \Omega_0 >}{{(P k_f^2)}^{2/3}}$  \
# 0 0.0108     inf  inf                                            1
# 1 0.0109     inf  inf                                            1
# 2  0.109     inf  inf                                            1
# 3  0.109     inf  inf                                            1
# 4   0.11     inf  inf                                            1
#
#                                       $E$  \
# 0  <xarray.DataArray ()>\narray(4.791503)
# 1  <xarray.DataArray ()>\narray(3.239999)
# 2  <xarray.DataArray ()>\narray(2.255547)
# 3  <xarray.DataArray ()>\narray(2.352529)
# 4  <xarray.DataArray ()>\narray(2.481549)
#
#                                           $t_{stat}$  \
# 0  <xarray.DataArray 't' ()>\narray(7.102083)\nCo...
# 1  <xarray.DataArray 't' ()>\narray(4.81875)\nCoo...
# 2  <xarray.DataArray 't' ()>\narray(3.542874)\nCo...
# 3  <xarray.DataArray 't' ()>\narray(3.725254)\nCo...
# 4  <xarray.DataArray 't' ()>\narray(4.012738)\nCo...
#
#                                           $t_{\max}$             short name
# 0  <xarray.DataArray 't' ()>\narray(24.901563)\nC...  noise_c100nh2880Buinf
# 1  <xarray.DataArray 't' ()>\narray(24.90625)\nCo...   noise_c100nh960Buinf
# 2  <xarray.DataArray 't' ()>\narray(24.918357)\nC...   noise_c10nh1920Buinf
# 3  <xarray.DataArray 't' ()>\narray(24.953155)\nC...   noise_c10nh2880Buinf
# 4  <xarray.DataArray 't' ()>\narray(24.949369)\nC...   noise_c10nh3840Buinf

# %%
numeric_columns = pd_columns.copy()
numeric_columns.remove('short name')
df_lap[numeric_columns] = df_lap[numeric_columns].applymap(float)

# %%
df_lap
# Out:
#     $n$  $c$  $\nu_8$  $\nu_2$  $f$  $\epsilon$  $\frac{k_{diss}}{k_f}$  \
# 0  2880  100        0   0.0328    0       0.961                    67.9
# 1   960  100        0   0.0985    0       0.976                    22.6
# 2  1920   10        0   0.0492    0       0.985                    45.3
# 3  2880   10        0   0.0328    0       0.984                    67.9
# 4  3840   10        0   0.0246    0       0.993                    90.5
# 5  7680   10        0   0.0123    0           1                     181
# 6   960   10        0   0.0985    0       0.998                    22.6
# 7  2880  200        0   0.0328    0       0.928                    67.9
# 8   960  200        0   0.0985    0       0.988                    22.6
# 9  2880   20        0   0.0328    0       0.982                    67.9
# 10  960   20        0   0.0985    0       0.994                    22.6
# 11 2880   40        0   0.0328    0       0.981                    67.9
# 12  960   40        0   0.0985    0       0.985                    22.6
#
#      $F_f$  $Ro_f$  $Bu$  $\frac{<\bf \Omega_0 >}{{(P k_f^2)}^{2/3}}$  $E$  \
# 0   0.0108     inf   inf                                            1 4.79
# 1   0.0109     inf   inf                                            1 3.24
# 2    0.109     inf   inf                                            1 2.26
# 3    0.109     inf   inf                                            1 2.35
# 4     0.11     inf   inf                                            1 2.48
# 5     0.11     inf   inf                                            1 2.87
# 6     0.11     inf   inf                                            1 2.04
# 7  0.00536     inf   inf                                            1 6.27
# 8  0.00547     inf   inf                                            1 4.01
# 9   0.0546     inf   inf                                            1 2.77
# 10  0.0548     inf   inf                                            1 2.19
# 11  0.0273     inf   inf                                            1  3.4
# 12  0.0273     inf   inf                                            1  2.5
#
#     $t_{stat}$  $t_{\max}$             short name
# 0          7.1        24.9  noise_c100nh2880Buinf
# 1         4.82        24.9   noise_c100nh960Buinf
# 2         3.54        24.9   noise_c10nh1920Buinf
# 3         3.73          25   noise_c10nh2880Buinf
# 4         4.01        24.9   noise_c10nh3840Buinf
# 5         3.61          25   noise_c10nh7680Buinf
# 6         3.44          25    noise_c10nh960Buinf
# 7          8.9        24.9  noise_c200nh2880Buinf
# 8         6.01          25   noise_c200nh960Buinf
# 9         4.43        24.9   noise_c20nh2880Buinf
# 10        3.76          25    noise_c20nh960Buinf
# 11        5.31        24.9   noise_c40nh2880Buinf
# 12        4.01          25    noise_c40nh960Buinf

# %%
df_lap = sort_reindex(df_lap)
df_lap
# Out:
#     $n$  $c$  $\nu_8$  $\nu_2$  $f$  $\epsilon$  $\frac{k_{diss}}{k_f}$  \
# 1   960   10        0   0.0985    0       0.998                    22.6
# 2  1920   10        0   0.0492    0       0.985                    45.3
# 3  2880   10        0   0.0328    0       0.984                    67.9
# 4  3840   10        0   0.0246    0       0.993                    90.5
# 5  7680   10        0   0.0123    0           1                     181
# 6   960   20        0   0.0985    0       0.994                    22.6
# 7  2880   20        0   0.0328    0       0.982                    67.9
# 8   960   40        0   0.0985    0       0.985                    22.6
# 9  2880   40        0   0.0328    0       0.981                    67.9
# 10  960  100        0   0.0985    0       0.976                    22.6
# 11 2880  100        0   0.0328    0       0.961                    67.9
# 12  960  200        0   0.0985    0       0.988                    22.6
# 13 2880  200        0   0.0328    0       0.928                    67.9
#
#      $F_f$  $Ro_f$  $Bu$  $\frac{<\bf \Omega_0 >}{{(P k_f^2)}^{2/3}}$  $E$  \
# 1     0.11     inf   inf                                            1 2.04
# 2    0.109     inf   inf                                            1 2.26
# 3    0.109     inf   inf                                            1 2.35
# 4     0.11     inf   inf                                            1 2.48
# 5     0.11     inf   inf                                            1 2.87
# 6   0.0548     inf   inf                                            1 2.19
# 7   0.0546     inf   inf                                            1 2.77
# 8   0.0273     inf   inf                                            1  2.5
# 9   0.0273     inf   inf                                            1  3.4
# 10  0.0109     inf   inf                                            1 3.24
# 11  0.0108     inf   inf                                            1 4.79
# 12 0.00547     inf   inf                                            1 4.01
# 13 0.00536     inf   inf                                            1 6.27
#
#     $t_{stat}$  $t_{\max}$             short name
# 1         3.44          25    noise_c10nh960Buinf
# 2         3.54        24.9   noise_c10nh1920Buinf
# 3         3.73          25   noise_c10nh2880Buinf
# 4         4.01        24.9   noise_c10nh3840Buinf
# 5         3.61          25   noise_c10nh7680Buinf
# 6         3.76          25    noise_c20nh960Buinf
# 7         4.43        24.9   noise_c20nh2880Buinf
# 8         4.01          25    noise_c40nh960Buinf
# 9         5.31        24.9   noise_c40nh2880Buinf
# 10        4.82        24.9   noise_c100nh960Buinf
# 11         7.1        24.9  noise_c100nh2880Buinf
# 12        6.01          25   noise_c200nh960Buinf
# 13         8.9        24.9  noise_c200nh2880Buinf

# %% [markdown]
# # To $\LaTeX$

# %%
filename = '../Latex/table_runs_lap.tex'
to_latex(df_lap, ['$f$', r'$\nu_8$', '$Ro_f$', '$Bu$', EFR, '$E$', '$t_{stat}$', 'short name'], filename)

# %% [markdown]
# # To CSV

# %%
df_lap.to_csv("dataframes/df_lap.csv")
# Out:
# scipy == 1.1.0 ; pandas == 0.23.4 ; numpy == 1.15.1
