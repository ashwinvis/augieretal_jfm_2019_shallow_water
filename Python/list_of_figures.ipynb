# %% [markdown]
# # List of figures

# %% [markdown]
# A brief description of the figure and the run number are mentioned as headings. The filename can also be seen in the block just above the figures.

# %%
# %load_ext autoreload
# %autoreload 2
# %aimport fluidsim

# %%
# %%capture
# %run table.ipynb

# %%
import os
from IPython.display import Image
from IPython.display import IFrame


class PDF(IFrame):
    def __init__(self, path):
        super().__init__(os.path.abspath(path), width=600, height=300)

# %% [markdown]
# Fig 1. Space-average energy vs time - to be skipped.

# %% [markdown]
# ## Fig 2: Spectral energy budget decomposed into KE and APE: W14

# %%
# %%capture
# %run make_fig_spect_energy_budg_c=100_N=3840.py r

# %%
Image(filename='../Pyfig/fig_spect_energy_budg_c=100_N=3840.png')

# %% [markdown]
# ## Fig 3: Third order structure functions: W7

# %%
# %%capture
# %run make_fig_Kolmo_c=20_N=3840.py r

# %%
Image(filename='../Pyfig/fig_Kolmo_c=20_N=3840.png')

# %%
# %%capture
# %run make_fig_flux_struct_combined.py r

# %%
Image(filename='../Pyfig/fig_flux_struct_combined.png')

# %% [markdown]
# ## Fig 4: Spatio-temporal spectra: W7

# %% [markdown]
# Please use the old figure, since I don't have sufficient temporal resolution in my data

# %% [markdown]
# ## Fig 5: Time- and space- averaged energy: W1 to W20

# %%
# %%capture # --no-display
from base_fig_energy import plot_energy

fig, ax = plot_energy(df_w)
path_fig = '../Pyfig/fig_energy_w.pdf'
fig.savefig(path_fig)
# Image(path_fig)

# %% [markdown]
# The dotted lines represent the curve-fitted values for the model function, $E/\sqrt{\epsilon} = C_n \sqrt{L_f c} $

# %% [markdown]
# ## Fig 6: Energy spectra for different wave speeds

# %% [markdown]
# Work in progress

# %% [markdown]
# ## Fig 7: Compensated energy spectra: W15

# %%
# %%capture
# %run make_fig_spectra_c=100_nh=7680.py r

# %%
Image('../Pyfig/fig_spectra_c=100_nh=7680.png')

# %% [markdown]
# ## Fig 8: Snapshots of physical fields: W6, W17

# %%
# %%capture
# %run make_fig_phys_fields_wave.py r

# %%
Image(filename='../Pyfig/fig_phys_fields_wave.png')

# %% [markdown]
# ## Fig 9: Compensated 5th order structure functions

# %% [markdown]
# ## Fig 10: Exponents of structure functions

# %% [markdown]
# ## Fig 11: Ratio of the lateral-transverse structure functions: W8

# %%
# %%capture
# %run make_fig_ratio_strfct.py r
# Out:
# Making Figure fig_ratio_strfct.pdf..
# Add parameter attributes:  {'beta'}
# Add parameter attributes:  {'NO_SHEAR_MODES'}
# Add parameter attributes:  {'cfl_coef', 'deltat_max'}
# Add parameter attributes:  {'modif_after_init'}
# Add parameter attributes:  {'enable'}
# Add parameter children:  {'normalized', 'tcrandom'}
# Add parameter attributes:  {'which_root', 'type'}
# Add parameter attributes:  {'only_positive'}
# Add parameter attributes:  {'time_correlation'}
# params.oper.type_fft FFTWCCY -> default
# *************************************
# Program fluidsim
# sim:                <class 'fluidsim.solvers.sw1l.onlywaves.solver.Simul'>
# sim.oper:           <class 'fluidsim.solvers.sw1l.operators.OperatorsPseudoSpectralSW1L'>
# sim.output:         <class 'fluidsim.solvers.sw1l.onlywaves.output.OutputSW1LWaves'>
# sim.state:          <class 'fluidsim.solvers.sw1l.onlywaves.state.StateSW1LWaves'>
# sim.time_stepping:  <class 'fluidsim.base.time_stepping.pseudo_spect_cy.TimeSteppingPseudoSpectral'>
# sim.init_fields:    <class 'fluidsim.solvers.sw1l.init_fields.InitFieldsSW1L'>
#
# solver SW1Lwaves, RK4 and sequential,
# type fft: fluidfft.fft2d.with_pyfftw
# nx =      4 ; ny =      4
# lx = 50 ; ly = 50
# path_run =
# /media/avmo/lacie/13KTH/noise/SW1Lwaves_NOISE2_c=20_L=50.x50._7680x7680_2016-09-27_18-45-04
# init_fields.type: constant
#
# Initialization outputs:
# sim.output.increments:        <class 'fluidsim.base.output.increments.IncrementsSW1L'>
# sim.output.phys_fields:       <class 'fluidsim.base.output.phys_fields2d.PhysFieldsBase2D'>
# sim.output.pdf:               <class 'fluidsim.base.output.prob_dens_func.ProbaDensityFunc'>
# sim.output.spatial_means:     <class 'fluidsim.solvers.sw1l.output.spatial_means.SpatialMeansSW1L'>
# sim.output.spectra:           <class 'fluidsim.solvers.sw1l.output.spectra.SpectraSW1LNormalMode'>
# sim.output.spect_energy_budg: <class 'fluidsim.solvers.sw1l.output.spect_energy_budget.SpectralEnergyBudgetSW1L'>
# sim.output.time_signals_fft:  <class 'fluidsim.base.output.time_signals_fft.TimeSignalsK'>
#
# Memory usage at the end of init. (equiv. seq.): 417.89453125 Mo
# Size of state_spect (equiv. seq.): 0.000384 Mo
# c2 =    400 ; f =      0 ; kd2 =      0
# plot(tmin=10, tmax=1000, delta_t=0.50)
# plot structure functions
# tmin =  10.0033 ; tmax =  119.522 ; delta_t = 0.500092
# imin =       20 ; imax =      239 ; delta_i =        1
# Skipping calculation because it exists in cache.
# Skipping calculation because it exists in cache.
# Skipping calculation because it exists in cache.
# Skipping calculation because it exists in cache.
# Skipping calculation because it exists in cache.
# Skipping calculation because it exists in cache.
# Skipping calculation because it exists in cache.
# Skipping calculation because it exists in cache.
# Skipping calculation because it exists in cache.
# Skipping calculation because it exists in cache.

# %%
Image("../Pyfig/fig_ratio_strfct.png")

# %% [markdown]
# ## Fig 12: Flatness: W8

# %%
# %%capture
# %run make_fig_flatness.py

# %%
Image("../Pyfig/fig_flatness.png")

# %% [markdown]
# The right subplot requires atmospheric data

# %% [markdown]
# ## Fig 13: Effect of global rotation: Energy vs $1/Bu$, Spectra

# %% [markdown]
# ## Fig 14: Effect of initial enstrophy: Energy vs $1/Bu$, Spectra
