# %%
# %load_ext autoreload
# %autoreload 2
# %aimport fluidsim

import os
from IPython.display import Image
from IPython.display import IFrame


class PDF(IFrame):
    def __init__(self, path):
        super().__init__(os.path.abspath(path), width=600, height=300)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Fig 1. Space-average energy vs time

# %%
# %%capture
# %run make_fig_Emean_time.py r

# %%
Image(filename='../Pyfig/fig_Emean_time.png')

# %% [markdown]
# ## Fig 2: Time- and space- averaged energy: W1 to W20

# %%
# %%capture --no-display
# %run make_fig_energy_w.py r
Image("../Pyfig/fig_energy_w.png")

# %% [markdown]
# The dotted lines represent the curve-fitted values for the model function, $E/\sqrt{\epsilon} = C_n \sqrt{L_f c} $

# %% [markdown]
# ## Fig 3: Spectral energy flux and Third order structure functions: W7

# %%
# %%capture
# %run make_fig_flux_struct_combined.py r

# %%
Image(filename='../Pyfig/fig_flux_struct_combined.png')

# %% [markdown]
# ## Fig 4: Spatio-temporal spectra: W7

# %%
PDF("../Old/Figs/fig_spatiotempspectra_c20_Nh3840.eps")

# %% [markdown]
# ## Fig 5: Snapshots of physical fields: W6, W17

# %%
# %%capture
# %run make_fig_phys_fields_wave.py r

# %%
Image(filename='../Pyfig/fig_phys_fields_wave.png')

# %% [markdown]
# ## Fig 6: Shock separation d vs Fr

# %%
# %%capture
# %run shock_population.ipynb

# %%
Image("../Pyfig/fig_shock_sep.png")

# %% [markdown]
# ## Fig 7: Scaling of structure functions

# %%
# %%capture
# %run make_fig_struct_order_246.py r

# %%
Image("../Pyfig/fig_struct_order_246.png")

# %% [markdown]
# ## Fig 9: Compensated 5th order structure functions

# %%
# %%capture
# %run make_fig_struct_order_5.py r

# %%
Image("../Pyfig/fig_struct_order_5.png")

# %% [markdown]
# ## Fig 10: Compensated 4th and 6th order structure functions of $c\delta h$

# %%
# %%capture
# %run make_fig_struct_eta_order_46.py r

# %%
Image("../Pyfig/fig_struct_eta_order_46.png")

# %% [markdown]
# ## Fig 11: Ratio of lateral and transverse structure functions

# %%
# %%capture
# %run make_fig_ratio_strfct.py r

# %%
Image("../Pyfig/fig_ratio_strfct.png")

# %% [markdown]
# ## Fig 12: Flatness: W8

# %%
# %%capture --no-display
# %run make_fig_flatness.py r

# %%
Image("../Pyfig/fig_flatness.png")

# %% [markdown]
# ## Fig 13: Compensated energy spectra: W15

# %%
# %%capture
# %run make_fig_spectra.py r

# %%
Image('../Pyfig/fig_spectra.png')
