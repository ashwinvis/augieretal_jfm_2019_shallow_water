# %% [markdown]
# # Load Data -> Pandas Dataframe -> Latex tables

# %%
# %matplotlib ipympl
# %run ../Python/paths.py
# %run ../Python/base.py
# Out:
# /usr/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
import pandas as pd
from pandas import DataFrame

def float_format(val, *args):
    # if isinstance(val, int):
    if val.is_integer():
        return '{:d}'.format(int(val), *args)
    else:
        return '{:.4}'.format(val, *args)

pd.options.display.float_format = float_format

df_paths = DataFrame({'key': list(paths_sim.keys()), 'path': list(paths_sim.values())},)
print(len(df_paths), 'directories')

def get_row(df, col_name, col_val):
    return df[df[col_name] == col_val]
# Out:
# 57 directories

# %% [markdown]
# # Load them!

# %%
df_noise = DataFrame(columns=pd_columns)
df_vort = DataFrame(columns=pd_columns)

# %%
# %%capture

for row in df_paths.values:
    key = row[0]
    path = row[1]
    keyparams = keyparams_from_path(path)
    s = pandas_from_path(path, key)

    if keyparams[0] == 'noise':
        df_noise = df_noise.append(s, ignore_index=True)
    else:
        df_vort = df_vort.append(s, ignore_index=True)

numeric_columns = pd_columns
numeric_columns.remove('short name')
df_noise[numeric_columns] = df_noise[numeric_columns].apply(pd.to_numeric)
df_vort[numeric_columns] = df_vort[numeric_columns].apply(pd.to_numeric)

# %%
def clean_up(df):
    df = df[
        df["$n$"]>=960
    ]
    df = df[df["$t_{stat}$"] < df["$t_{\max}$"]]
    return df

def sort_reindex(df, prefix=None):
    df = df.sort_values(by=[r'$c$', r'$n$', r'$Bu$'])
    if prefix is not None:
        df.index = [f'{prefix}{i}' for i in range(1,len(df) + 1)]
    else:
        df.index = range(1,len(df) + 1)
    # df = df.reindex(range(1,len(df) + 1))
    return df

# %%
df_vort = clean_up(df_vort)
df_vort = sort_reindex(df_vort)
df_vort
# Out:
#      $n$  $c$   $\nu_8$   $f$  $\epsilon$  $\frac{k_{diss}}{k_f}$    $F_f$  \
# 1   1920   20 1.112e-12  7.54       1.032                   56.59  0.05551
# 2   1920   20 1.112e-12 3.372       1.027                   56.59  0.05543
# 3   1920   20 1.112e-12     0       1.018                   56.59  0.05527
# 4   1920   20 1.112e-12     0       1.032                   56.59  0.05552
# 5   1920   20 1.112e-12     0        1.04                   56.59  0.05566
# 6   1920   20 1.112e-12     0       1.055                   56.59  0.05593
# 7   1920  100 1.112e-12  75.4      0.9323                   56.59  0.01073
# 8   1920  100 1.112e-12  75.4      0.9147                   56.59  0.01067
# 9   1920  100 1.112e-12  75.4       1.143                   56.59  0.01149
# 10  1920  100 1.112e-12 53.31       1.062                   56.59  0.01121
# 11  1920  100 1.112e-12 53.31      0.9914                   56.59  0.01096
# 12  1920  100 1.112e-12 53.31       0.998                   56.59  0.01098
# 13  1920  100 1.112e-12  37.7       1.041                   56.59  0.01113
# 14  1920  100 1.112e-12  37.7       1.247                   56.59  0.01183
# 15  1920  100 1.112e-12  37.7        1.28                   56.59  0.01193
# 16  1920  100 1.112e-12  37.7       1.036                   56.59  0.01112
# 17  1920  100 1.112e-12  37.7       1.043                   56.59  0.01114
# 18  1920  100 1.112e-12     0       1.068                   56.59  0.01123
# 19  1920  100 1.112e-12     0       1.022                   56.59  0.01107
# 20  1920  100 1.112e-12     0       1.142                   56.59  0.01148
# 21  1920  100 1.112e-12     0       1.018                   56.59  0.01105
# 22  1920  100 1.112e-12     0       1.012                   56.59  0.01103
# 23  1920  400 1.112e-12     0       1.041                   56.59 0.002784
# 24  1920  400 1.112e-12     0        1.08                   56.59 0.002819
# 25  1920  400 1.112e-12     0       1.174                   56.59 0.002898
# 26  1920  400 1.112e-12     0       1.027                   56.59 0.002771
# 27  1920  400 1.112e-12     0       1.143                   56.59 0.002872
#
#     $Ro_f$  $Bu$  $\frac{<\bf \Omega_0 >}{{(P k_f^2)}^{2/3}}$  $t_{stat}$  \
# 1    0.111     4                                         0.01       8.073
# 2   0.2479    20                                            1        11.8
# 3      inf   inf                                         0.01       5.495
# 4      inf   inf                                           10       7.323
# 5      inf   inf                                            1       8.536
# 6      inf   inf                                          0.1       6.052
# 7  0.01073     1                                         0.01       22.53
# 8  0.01067     1                                          0.1       22.78
# 9  0.01149     1                                            1        23.0
# 10 0.01585     2                                            1       19.53
# 11 0.01549     2                                         0.01       19.21
# 12 0.01553     2                                          0.1       19.31
# 13 0.02227     4                                          0.1       16.61
# 14 0.02365     4                                           10       13.18
# 15 0.02386     4                                          100       5.511
# 16 0.02224     4                                         0.01       16.85
# 17 0.02228     4                                            1       16.38
# 18     inf   inf                                           10       8.853
# 19     inf   inf                                         0.01       11.08
# 20     inf   inf                                          100       4.973
# 21     inf   inf                                          0.1       11.15
# 22     inf   inf                                            1       11.54
# 23     inf   inf                                            1       19.68
# 24     inf   inf                                          0.1       19.38
# 25     inf   inf                                           10       18.56
# 26     inf   inf                                         0.01       22.02
# 27     inf   inf                                          100       13.08
#
#     $t_{\max}$                              short name
# 1        99.86   vortex_grid_c20nh1920Bu4.0efr1.00e-02
# 2        99.85  vortex_grid_c20nh1920Bu20.0efr1.00e+00
# 3        49.83   vortex_grid_c20nh1920Buinfefr1.00e-02
# 4        99.84   vortex_grid_c20nh1920Buinfefr1.00e+01
# 5        49.89   vortex_grid_c20nh1920Buinfefr1.00e+00
# 6        99.86   vortex_grid_c20nh1920Buinfefr1.00e-01
# 7        99.81  vortex_grid_c100nh1920Bu1.0efr1.00e-02
# 8        99.81  vortex_grid_c100nh1920Bu1.0efr1.00e-01
# 9        99.81  vortex_grid_c100nh1920Bu1.0efr1.00e+00
# 10       99.81  vortex_grid_c100nh1920Bu2.0efr1.00e+00
# 11       99.81  vortex_grid_c100nh1920Bu2.0efr1.00e-02
# 12       99.81  vortex_grid_c100nh1920Bu2.0efr1.00e-01
# 13       99.86  vortex_grid_c100nh1920Bu4.0efr1.00e-01
# 14       99.86  vortex_grid_c100nh1920Bu4.0efr1.00e+01
# 15       99.86  vortex_grid_c100nh1920Bu4.0efr1.00e+02
# 16       99.86  vortex_grid_c100nh1920Bu4.0efr1.00e-02
# 17       99.86  vortex_grid_c100nh1920Bu4.0efr1.00e+00
# 18       99.87  vortex_grid_c100nh1920Buinfefr1.00e+01
# 19       99.87  vortex_grid_c100nh1920Buinfefr1.00e-02
# 20       49.88  vortex_grid_c100nh1920Buinfefr1.00e+02
# 21       99.87  vortex_grid_c100nh1920Buinfefr1.00e-01
# 22       49.88  vortex_grid_c100nh1920Buinfefr1.00e+00
# 23       49.83  vortex_grid_c400nh1920Buinfefr1.00e+00
# 24       99.86  vortex_grid_c400nh1920Buinfefr1.00e-01
# 25       99.86  vortex_grid_c400nh1920Buinfefr1.00e+01
# 26       49.83  vortex_grid_c400nh1920Buinfefr1.00e-02
# 27       49.83  vortex_grid_c400nh1920Buinfefr1.00e+02

# %%
df_noise = clean_up(df_noise)
df_noise = sort_reindex(df_noise)
df_noise
# Out:
#      $n$  $c$   $\nu_8$   $f$  $\epsilon$  $\frac{k_{diss}}{k_f}$    $F_f$  \
# 1    960   10 1.561e-10     0       1.036                   28.83   0.1112
# 2   1920   10 9.677e-13     0       1.061                   57.67    0.112
# 3   3840   10     6e-15     0       1.117                   115.3    0.114
# 4   7680   10 3.725e-17     0       1.273                   230.7   0.1191
# 5    960   20 1.562e-10     0       1.014                   28.83  0.05519
# 6   1920   20 9.677e-13 21.33      0.8378                   57.67  0.05179
# 7   1920   20 9.677e-13 15.08      0.8944                   57.67  0.05293
# 8   1920   20 9.677e-13 10.66      0.9382                   57.67  0.05378
# 9   1920   20 9.677e-13  7.54      0.9719                   57.67  0.05441
# 10  1920   20 9.687e-13     0       1.059                   57.67    0.056
# 11  3840   20 6.007e-15     0       1.087                   115.3  0.05648
# 12  7680   20 3.725e-17     0       1.208                   230.7  0.05851
# 13   960   40 1.561e-10     0       1.001                   28.83  0.02747
# 14  1920   40 9.677e-13     0      0.9978                   57.67  0.02745
# 15  3840   40     6e-15     0       1.064                   115.3  0.02804
# 16   960  100 1.562e-10     0      0.9995                   28.83  0.01099
# 17  1920  100 9.687e-13     0        1.01                   57.67  0.01102
# 18  3840  100 6.007e-15     0       1.062                   115.3  0.01121
# 19  7680  100 3.725e-17     0       1.217                   230.7  0.01173
# 20   960  400 1.562e-10     0       1.141                   28.83 0.002871
# 21  1920  400 9.687e-13     0       1.152                   57.67 0.002879
# 22  3840  400 6.007e-15     0       1.123                   115.3 0.002855
# 23  7680  400 3.725e-17     0      0.6546                   230.7 0.002385
# 24   960  700 1.561e-10     0        1.27                   28.83   0.0017
# 25  1920  700 9.677e-13     0       1.054                   57.67 0.001597
#
#     $Ro_f$  $Bu$  $\frac{<\bf \Omega_0 >}{{(P k_f^2)}^{2/3}}$  $t_{stat}$  \
# 1      inf   inf                                            1       19.26
# 2      inf   inf                                            1       3.907
# 3      inf   inf                                            1       14.58
# 4      inf   inf                                            1       13.13
# 5      inf   inf                                            1       13.96
# 6  0.03662   0.5                                            1       10.89
# 7  0.05293     1                                            1       7.914
# 8  0.07606     2                                            1       6.228
# 9   0.1088     4                                            1       11.59
# 10     inf   inf                                            1       4.787
# 11     inf   inf                                            1       17.39
# 12     inf   inf                                            1       8.665
# 13     inf   inf                                            1       16.84
# 14     inf   inf                                            1       7.775
# 15     inf   inf                                            1       9.593
# 16     inf   inf                                            1       9.476
# 17     inf   inf                                            1       10.09
# 18     inf   inf                                            1       13.63
# 19     inf   inf                                            1        17.5
# 20     inf   inf                                            1       15.82
# 21     inf   inf                                            1       21.12
# 22     inf   inf                                            1       25.31
# 23     inf   inf                                            1       22.12
# 24     inf   inf                                            1       20.93
# 25     inf   inf                                            1       23.76
#
#     $t_{\max}$             short name
# 1        49.88    noise_c10nh960Buinf
# 2        49.84   noise_c10nh1920Buinf
# 3        49.86   noise_c10nh3840Buinf
# 4        16.94   noise_c10nh7680Buinf
# 5        49.87    noise_c20nh960Buinf
# 6        99.87   noise_c20nh1920Bu0.5
# 7        99.83   noise_c20nh1920Bu1.0
# 8        99.83   noise_c20nh1920Bu2.0
# 9        99.84   noise_c20nh1920Bu4.0
# 10       119.9   noise_c20nh1920Buinf
# 11       119.9   noise_c20nh3840Buinf
# 12       119.8   noise_c20nh7680Buinf
# 13       49.83    noise_c40nh960Buinf
# 14       49.83   noise_c40nh1920Buinf
# 15       49.83   noise_c40nh3840Buinf
# 16       49.84   noise_c100nh960Buinf
# 17       119.8  noise_c100nh1920Buinf
# 18       119.9  noise_c100nh3840Buinf
# 19       95.81  noise_c100nh7680Buinf
# 20       119.9   noise_c400nh960Buinf
# 21       119.8  noise_c400nh1920Buinf
# 22       119.4  noise_c400nh3840Buinf
# 23        22.3  noise_c400nh7680Buinf
# 24       49.83   noise_c700nh960Buinf
# 25       49.82  noise_c700nh1920Buinf

# %% [markdown]
# # Prepare final dataframes

# %% [markdown]
# ### Only waves

# %%
groups = df_noise.groupby(r'$Ro_f$')

df_w = sort_reindex(
    groups.filter(
        lambda x:all(x['$Ro_f$'] == np.inf),
        dropna=True
    ),
    prefix='W'
)
df_w
# Out:
#       $n$  $c$   $\nu_8$  $f$  $\epsilon$  $\frac{k_{diss}}{k_f}$    $F_f$  \
# W1    960   10 1.561e-10    0       1.036                   28.83   0.1112
# W2   1920   10 9.677e-13    0       1.061                   57.67    0.112
# W3   3840   10     6e-15    0       1.117                   115.3    0.114
# W4   7680   10 3.725e-17    0       1.273                   230.7   0.1191
# W5    960   20 1.562e-10    0       1.014                   28.83  0.05519
# W6   1920   20 9.687e-13    0       1.059                   57.67    0.056
# W7   3840   20 6.007e-15    0       1.087                   115.3  0.05648
# W8   7680   20 3.725e-17    0       1.208                   230.7  0.05851
# W9    960   40 1.561e-10    0       1.001                   28.83  0.02747
# W10  1920   40 9.677e-13    0      0.9978                   57.67  0.02745
# W11  3840   40     6e-15    0       1.064                   115.3  0.02804
# W12   960  100 1.562e-10    0      0.9995                   28.83  0.01099
# W13  1920  100 9.687e-13    0        1.01                   57.67  0.01102
# W14  3840  100 6.007e-15    0       1.062                   115.3  0.01121
# W15  7680  100 3.725e-17    0       1.217                   230.7  0.01173
# W16   960  400 1.562e-10    0       1.141                   28.83 0.002871
# W17  1920  400 9.687e-13    0       1.152                   57.67 0.002879
# W18  3840  400 6.007e-15    0       1.123                   115.3 0.002855
# W19  7680  400 3.725e-17    0      0.6546                   230.7 0.002385
# W20   960  700 1.561e-10    0        1.27                   28.83   0.0017
# W21  1920  700 9.677e-13    0       1.054                   57.67 0.001597
#
#      $Ro_f$  $Bu$  $\frac{<\bf \Omega_0 >}{{(P k_f^2)}^{2/3}}$  $t_{stat}$  \
# W1      inf   inf                                            1       19.26
# W2      inf   inf                                            1       3.907
# W3      inf   inf                                            1       14.58
# W4      inf   inf                                            1       13.13
# W5      inf   inf                                            1       13.96
# W6      inf   inf                                            1       4.787
# W7      inf   inf                                            1       17.39
# W8      inf   inf                                            1       8.665
# W9      inf   inf                                            1       16.84
# W10     inf   inf                                            1       7.775
# W11     inf   inf                                            1       9.593
# W12     inf   inf                                            1       9.476
# W13     inf   inf                                            1       10.09
# W14     inf   inf                                            1       13.63
# W15     inf   inf                                            1        17.5
# W16     inf   inf                                            1       15.82
# W17     inf   inf                                            1       21.12
# W18     inf   inf                                            1       25.31
# W19     inf   inf                                            1       22.12
# W20     inf   inf                                            1       20.93
# W21     inf   inf                                            1       23.76
#
#      $t_{\max}$             short name
# W1        49.88    noise_c10nh960Buinf
# W2        49.84   noise_c10nh1920Buinf
# W3        49.86   noise_c10nh3840Buinf
# W4        16.94   noise_c10nh7680Buinf
# W5        49.87    noise_c20nh960Buinf
# W6        119.9   noise_c20nh1920Buinf
# W7        119.9   noise_c20nh3840Buinf
# W8        119.8   noise_c20nh7680Buinf
# W9        49.83    noise_c40nh960Buinf
# W10       49.83   noise_c40nh1920Buinf
# W11       49.83   noise_c40nh3840Buinf
# W12       49.84   noise_c100nh960Buinf
# W13       119.8  noise_c100nh1920Buinf
# W14       119.9  noise_c100nh3840Buinf
# W15       95.81  noise_c100nh7680Buinf
# W16       119.9   noise_c400nh960Buinf
# W17       119.8  noise_c400nh1920Buinf
# W18       119.4  noise_c400nh3840Buinf
# W19        22.3  noise_c400nh7680Buinf
# W20       49.83   noise_c700nh960Buinf
# W21       49.82  noise_c700nh1920Buinf

# %% [markdown]
# ### Only waves and rotation

# %%
"""
groups = df_noise.groupby(['$n$', '$c$'])

df_wr = sort_reindex(
    groups.filter(
        lambda x:all(x['$n$'] == 1920) and all(x['$c$'] == 20),
        dropna=True
    ),
    prefix='WR'
)
df_wr
"""
groups = df_noise.groupby(['$n$', '$Ro_f$'])

df_wr = sort_reindex(
    groups.filter(
        lambda x:all(x['$Ro_f$'] < np.inf),
        dropna=True
    ),
    prefix='WR'
)
df_wr
# Out:
#       $n$  $c$   $\nu_8$   $f$  $\epsilon$  $\frac{k_{diss}}{k_f}$   $F_f$  \
# WR1  1920   20 9.677e-13 21.33      0.8378                   57.67 0.05179
# WR2  1920   20 9.677e-13 15.08      0.8944                   57.67 0.05293
# WR3  1920   20 9.677e-13 10.66      0.9382                   57.67 0.05378
# WR4  1920   20 9.677e-13  7.54      0.9719                   57.67 0.05441
#
#      $Ro_f$  $Bu$  $\frac{<\bf \Omega_0 >}{{(P k_f^2)}^{2/3}}$  $t_{stat}$  \
# WR1 0.03662   0.5                                            1       10.89
# WR2 0.05293     1                                            1       7.914
# WR3 0.07606     2                                            1       6.228
# WR4  0.1088     4                                            1       11.59
#
#      $t_{\max}$            short name
# WR1       99.87  noise_c20nh1920Bu0.5
# WR2       99.83  noise_c20nh1920Bu1.0
# WR3       99.83  noise_c20nh1920Bu2.0
# WR4       99.84  noise_c20nh1920Bu4.0

# %% [markdown]
# ### Wave-vortex

# %%
groups = df_vort.groupby(r'$Ro_f$')

df_wv = sort_reindex(
    groups.filter(
        lambda x:all(x['$Ro_f$'] == np.inf),
        dropna=True
    ),
    prefix='WV'
)
df_wv
# Out:
#        $n$  $c$   $\nu_8$  $f$  $\epsilon$  $\frac{k_{diss}}{k_f}$    $F_f$  \
# WV1   1920   20 1.112e-12    0       1.018                   56.59  0.05527
# WV2   1920   20 1.112e-12    0       1.032                   56.59  0.05552
# WV3   1920   20 1.112e-12    0        1.04                   56.59  0.05566
# WV4   1920   20 1.112e-12    0       1.055                   56.59  0.05593
# WV5   1920  100 1.112e-12    0       1.068                   56.59  0.01123
# WV6   1920  100 1.112e-12    0       1.022                   56.59  0.01107
# WV7   1920  100 1.112e-12    0       1.142                   56.59  0.01148
# WV8   1920  100 1.112e-12    0       1.018                   56.59  0.01105
# WV9   1920  100 1.112e-12    0       1.012                   56.59  0.01103
# WV10  1920  400 1.112e-12    0       1.041                   56.59 0.002784
# WV11  1920  400 1.112e-12    0        1.08                   56.59 0.002819
# WV12  1920  400 1.112e-12    0       1.174                   56.59 0.002898
# WV13  1920  400 1.112e-12    0       1.027                   56.59 0.002771
# WV14  1920  400 1.112e-12    0       1.143                   56.59 0.002872
#
#       $Ro_f$  $Bu$  $\frac{<\bf \Omega_0 >}{{(P k_f^2)}^{2/3}}$  $t_{stat}$  \
# WV1      inf   inf                                         0.01       5.495
# WV2      inf   inf                                           10       7.323
# WV3      inf   inf                                            1       8.536
# WV4      inf   inf                                          0.1       6.052
# WV5      inf   inf                                           10       8.853
# WV6      inf   inf                                         0.01       11.08
# WV7      inf   inf                                          100       4.973
# WV8      inf   inf                                          0.1       11.15
# WV9      inf   inf                                            1       11.54
# WV10     inf   inf                                            1       19.68
# WV11     inf   inf                                          0.1       19.38
# WV12     inf   inf                                           10       18.56
# WV13     inf   inf                                         0.01       22.02
# WV14     inf   inf                                          100       13.08
#
#       $t_{\max}$                              short name
# WV1        49.83   vortex_grid_c20nh1920Buinfefr1.00e-02
# WV2        99.84   vortex_grid_c20nh1920Buinfefr1.00e+01
# WV3        49.89   vortex_grid_c20nh1920Buinfefr1.00e+00
# WV4        99.86   vortex_grid_c20nh1920Buinfefr1.00e-01
# WV5        99.87  vortex_grid_c100nh1920Buinfefr1.00e+01
# WV6        99.87  vortex_grid_c100nh1920Buinfefr1.00e-02
# WV7        49.88  vortex_grid_c100nh1920Buinfefr1.00e+02
# WV8        99.87  vortex_grid_c100nh1920Buinfefr1.00e-01
# WV9        49.88  vortex_grid_c100nh1920Buinfefr1.00e+00
# WV10       49.83  vortex_grid_c400nh1920Buinfefr1.00e+00
# WV11       99.86  vortex_grid_c400nh1920Buinfefr1.00e-01
# WV12       99.86  vortex_grid_c400nh1920Buinfefr1.00e+01
# WV13       49.83  vortex_grid_c400nh1920Buinfefr1.00e-02
# WV14       49.83  vortex_grid_c400nh1920Buinfefr1.00e+02

# %% [markdown]
# ### Waves-vortex and rotation

# %%
groups = df_vort.groupby(['$n$', '$Ro_f$'])

df_wvr = sort_reindex(
    groups.filter(
        lambda x:all(x['$Ro_f$'] < np.inf),
        dropna=True
    ),
    prefix='WVR'
)
df_wvr
# Out:
#         $n$  $c$   $\nu_8$   $f$  $\epsilon$  $\frac{k_{diss}}{k_f}$   $F_f$  \
# WVR1   1920   20 1.112e-12  7.54       1.032                   56.59 0.05551
# WVR2   1920   20 1.112e-12 3.372       1.027                   56.59 0.05543
# WVR3   1920  100 1.112e-12  75.4      0.9323                   56.59 0.01073
# WVR4   1920  100 1.112e-12  75.4      0.9147                   56.59 0.01067
# WVR5   1920  100 1.112e-12  75.4       1.143                   56.59 0.01149
# WVR6   1920  100 1.112e-12 53.31       1.062                   56.59 0.01121
# WVR7   1920  100 1.112e-12 53.31      0.9914                   56.59 0.01096
# WVR8   1920  100 1.112e-12 53.31       0.998                   56.59 0.01098
# WVR9   1920  100 1.112e-12  37.7       1.041                   56.59 0.01113
# WVR10  1920  100 1.112e-12  37.7       1.247                   56.59 0.01183
# WVR11  1920  100 1.112e-12  37.7        1.28                   56.59 0.01193
# WVR12  1920  100 1.112e-12  37.7       1.036                   56.59 0.01112
# WVR13  1920  100 1.112e-12  37.7       1.043                   56.59 0.01114
#
#        $Ro_f$  $Bu$  $\frac{<\bf \Omega_0 >}{{(P k_f^2)}^{2/3}}$  $t_{stat}$  \
# WVR1    0.111     4                                         0.01       8.073
# WVR2   0.2479    20                                            1        11.8
# WVR3  0.01073     1                                         0.01       22.53
# WVR4  0.01067     1                                          0.1       22.78
# WVR5  0.01149     1                                            1        23.0
# WVR6  0.01585     2                                            1       19.53
# WVR7  0.01549     2                                         0.01       19.21
# WVR8  0.01553     2                                          0.1       19.31
# WVR9  0.02227     4                                          0.1       16.61
# WVR10 0.02365     4                                           10       13.18
# WVR11 0.02386     4                                          100       5.511
# WVR12 0.02224     4                                         0.01       16.85
# WVR13 0.02228     4                                            1       16.38
#
#        $t_{\max}$                              short name
# WVR1        99.86   vortex_grid_c20nh1920Bu4.0efr1.00e-02
# WVR2        99.85  vortex_grid_c20nh1920Bu20.0efr1.00e+00
# WVR3        99.81  vortex_grid_c100nh1920Bu1.0efr1.00e-02
# WVR4        99.81  vortex_grid_c100nh1920Bu1.0efr1.00e-01
# WVR5        99.81  vortex_grid_c100nh1920Bu1.0efr1.00e+00
# WVR6        99.81  vortex_grid_c100nh1920Bu2.0efr1.00e+00
# WVR7        99.81  vortex_grid_c100nh1920Bu2.0efr1.00e-02
# WVR8        99.81  vortex_grid_c100nh1920Bu2.0efr1.00e-01
# WVR9        99.86  vortex_grid_c100nh1920Bu4.0efr1.00e-01
# WVR10       99.86  vortex_grid_c100nh1920Bu4.0efr1.00e+01
# WVR11       99.86  vortex_grid_c100nh1920Bu4.0efr1.00e+02
# WVR12       99.86  vortex_grid_c100nh1920Bu4.0efr1.00e-02
# WVR13       99.86  vortex_grid_c100nh1920Bu4.0efr1.00e+00

# %%
print(sum([len(df) for df in (df_w, df_wr, df_wv, df_wvr)]))
print(sum([len(df) for df in (df_noise, df_vort)]))
# Out:
# 52
# 52

# %% [markdown]
# # To $\LaTeX$

# %%
from IPython import display

def to_latex(df, strip_cols, filename=None):
    for col in strip_cols:
        if col in df:
            del df[col]
            
    output = df.to_latex(escape=False)

    if filename == '':
        print(output)
    elif filename == 'jupyter':
        display.display_html(df)
    else:
        with open(filename, 'a') as f:
            f.write(output)

# %%
import os

# filename = 'jupyter'
filename = '../Latex/table_runs.tex'
if os.path.exists(filename):
    os.remove(filename)

if filename.endswith('.tex'):
    with open(filename, 'a') as f:
        f.write(r"""
\documentclass[a4paper]{article}
\usepackage[margin=1in]{geometry}

\begin{document}
\section{List of runs}


\subsection{Glossary}
\begin{itemize}
    \item W : Only waves runs
    \item WR : Only waves runs with rotation
    \item WV : Wave-vortex runs
    \item WVR : Wave-vortex runs with rotation
    \item $t_{stat}$ : Time when the run is approximately stationary
    \item $t_{max}$ : Time until which the run was simulated
""")
        f.write(
            '    \item {} : Initial enstrophy - forcing power ratio'.format(EFR))
        f.write('\n\end{itemize}')
        f.write(
            '\n\n\subsection{Tables}\n')

    
to_latex(df_w, ['$f$', '$Ro_f$', '$Bu$', EFR, 'short name'], filename)
to_latex(df_wr, [EFR, r'short name'], filename)
to_latex(df_wv, ['$f$', '$Ro_f$', '$Bu$', 'short name'], filename)
to_latex(df_wvr, ['short name'], filename)


if filename.endswith('.tex'):
    with open(filename, 'a') as f:
        f.write('\end{document}')

# %%
# !pandoc  -V geometry:margin=1in -o ../Latex/table_runs.pdf ../Latex/table_runs.tex
